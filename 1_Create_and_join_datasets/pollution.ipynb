# %%
import pandas as pd
import numpy as np

# %%
df_pollution = pd.read_csv("C:\\Users\\celia\\Downloads\\pollution.csv")

# %%
df_pollution.shape
# Out:
# (222, 26)

# %%
df_pollution.head()
# Out:
#      Country Name Country Code  \
# 0     Afghanistan          AFG
# 1         Albania          ALB
# 2         Algeria          DZA
# 3  American Samoa          ASM
# 4         Andorra          AND
#
#                                          Series Name        Series Code  \
# 0  PM2.5 air pollution, mean annual exposure (mic...  EN.ATM.PM25.MC.M3
# 1  PM2.5 air pollution, mean annual exposure (mic...  EN.ATM.PM25.MC.M3
# 2  PM2.5 air pollution, mean annual exposure (mic...  EN.ATM.PM25.MC.M3
# 3  PM2.5 air pollution, mean annual exposure (mic...  EN.ATM.PM25.MC.M3
# 4  PM2.5 air pollution, mean annual exposure (mic...  EN.ATM.PM25.MC.M3
#
#   2000 [YR2000] 2001 [YR2001] 2002 [YR2002] 2003 [YR2003] 2004 [YR2004]  \
# 0   51.55453373            ..            ..            ..            ..
# 1   24.30286936            ..            ..            ..            ..
# 2   35.37684627            ..            ..            ..            ..
# ...

# %%
df_pollution.tail(10)
# Out:
#                                          Country Name Country Code  \
# 212                             Virgin Islands (U.S.)          VIR
# 213                                West Bank and Gaza          PSE
# 214                                       Yemen, Rep.          YEM
# 215                                            Zambia          ZMB
# 216                                          Zimbabwe          ZWE
# 217                                               NaN          NaN
# 218                                               NaN          NaN
# 219                                               NaN          NaN
# 220  Data from database: World Development Indicators          NaN
# 221                          Last Updated: 12/18/2023          NaN
#
#                                            Series Name        Series Code  \
# 212  PM2.5 air pollution, mean annual exposure (mic...  EN.ATM.PM25.MC.M3
# 213  PM2.5 air pollution, mean annual exposure (mic...  EN.ATM.PM25.MC.M3
# ...

# %%
df_pollution= df_pollution.iloc[:-5,]

# %%
df_pollution.tail(5)
# Out:
#               Country Name Country Code  \
# 212  Virgin Islands (U.S.)          VIR
# 213     West Bank and Gaza          PSE
# 214            Yemen, Rep.          YEM
# 215                 Zambia          ZMB
# 216               Zimbabwe          ZWE
#
#                                            Series Name        Series Code  \
# 212  PM2.5 air pollution, mean annual exposure (mic...  EN.ATM.PM25.MC.M3
# 213  PM2.5 air pollution, mean annual exposure (mic...  EN.ATM.PM25.MC.M3
# 214  PM2.5 air pollution, mean annual exposure (mic...  EN.ATM.PM25.MC.M3
# 215  PM2.5 air pollution, mean annual exposure (mic...  EN.ATM.PM25.MC.M3
# 216  PM2.5 air pollution, mean annual exposure (mic...  EN.ATM.PM25.MC.M3
#
#     2000 [YR2000] 2001 [YR2001] 2002 [YR2002] 2003 [YR2003] 2004 [YR2004]  \
# 212   8.675964872            ..            ..            ..            ..
# 213   31.57183418            ..            ..            ..            ..
# ...

# %%
df_pollution = df_pollution.drop(columns=['Series Name', 'Series Code'])

# %%
df_pollution.info(all)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 217 entries, 0 to 216
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country Name   217 non-null    object
#  1   Country Code   217 non-null    object
#  2   2000 [YR2000]  217 non-null    object
#  3   2001 [YR2001]  217 non-null    object
#  4   2002 [YR2002]  217 non-null    object
#  5   2003 [YR2003]  217 non-null    object
#  6   2004 [YR2004]  217 non-null    object
#  7   2005 [YR2005]  217 non-null    object
#  8   2006 [YR2006]  217 non-null    object
#  9   2007 [YR2007]  217 non-null    object
#  10  2008 [YR2008]  217 non-null    object
#  11  2009 [YR2009]  217 non-null    object
#  12  2010 [YR2010]  217 non-null    object
#  13  2011 [YR2011]  217 non-null    object
#  14  2012 [YR2012]  217 non-null    object
#  15  2013 [YR2013]  217 non-null    object
#  16  2014 [YR2014]  217 non-null    object
# ...

# %%
df_pollution.describe(include='all')
# Out:
#        Country Name Country Code 2000 [YR2000] 2001 [YR2001] 2002 [YR2002]  \
# count           217          217           217           217           217
# unique          217          217           201             1             1
# top     Afghanistan          AFG            ..            ..            ..
# freq              1            1            17           217           217
#
#        2003 [YR2003] 2004 [YR2004] 2005 [YR2005] 2006 [YR2006] 2007 [YR2007]  \
# count            217           217           217           217           217
# unique             1             1           201             1             1
# top               ..            ..            ..            ..            ..
# freq             217           217            17           217           217
#
#         ... 2012 [YR2012] 2013 [YR2013] 2014 [YR2014] 2015 [YR2015]  \
# count   ...           217           217           217           217
# ...

# %%
columns_to_modify = df_pollution.columns[2:]
columns_to_modify = columns_to_modify.str.replace(r'\[YR\d{4}\]','')
# Out:
# C:\Users\celia\AppData\Local\Temp\ipykernel_12396\3006064280.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   columns_to_modify = columns_to_modify.str.replace(r'\[YR\d{4}\]','')

# %%
columns_to_modify
# Out:
# Index(['2000 ', '2001 ', '2002 ', '2003 ', '2004 ', '2005 ', '2006 ', '2007 ',
#        '2008 ', '2009 ', '2010 ', '2011 ', '2012 ', '2013 ', '2014 ', '2015 ',
#        '2016 ', '2017 ', '2018 ', '2019 ', '2020 ', '2021 '],
#       dtype='object')

# %%
df_pollution.columns =['Country Name','Country Code', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
       '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
       '2016', '2017', '2018', '2019', '2020', '2021']

# %%
df_pollution_unpivot= df_pollution.melt(id_vars=['Country Name','Country Code'], var_name = 'Year', value_name= 'PM2.5_pollution')

# %%
df_pollution_unpivot
# Out:
#                Country Name Country Code  Year PM2.5_pollution
# 0               Afghanistan          AFG  2000     51.55453373
# 1                   Albania          ALB  2000     24.30286936
# 2                   Algeria          DZA  2000     35.37684627
# 3            American Samoa          ASM  2000     5.899967661
# 4                   Andorra          AND  2000      13.6184311
# ...                     ...          ...   ...             ...
# 4769  Virgin Islands (U.S.)          VIR  2021              ..
# 4770     West Bank and Gaza          PSE  2021              ..
# 4771            Yemen, Rep.          YEM  2021              ..
# 4772                 Zambia          ZMB  2021              ..
# 4773               Zimbabwe          ZWE  2021              ..
#
# [4774 rows x 4 columns]

# %%
df_pollution_unpivot.describe(include='all')
# Out:
#        Country Name Country Code  Year PM2.5_pollution
# count          4774         4774  4774            4774
# unique          217          217    22            2401
# top     Afghanistan          AFG  2000              ..
# freq             22           22   217            2374

# %%
mask = df_pollution_unpivot['PM2.5_pollution'].str.contains(r'\.\.', na=False)
print(df_pollution_unpivot[mask])
# Out:
#                 Country Name Country Code  Year PM2.5_pollution
# 9                      Aruba          ABW  2000              ..
# 27    British Virgin Islands          VGB  2000              ..
# 36            Cayman Islands          CYM  2000              ..
# 39           Channel Islands          CHI  2000              ..
# 50                   Curacao          CUW  2000              ..
# ...                      ...          ...   ...             ...
# 4769   Virgin Islands (U.S.)          VIR  2021              ..
# 4770      West Bank and Gaza          PSE  2021              ..
# 4771             Yemen, Rep.          YEM  2021              ..
# 4772                  Zambia          ZMB  2021              ..
# 4773                Zimbabwe          ZWE  2021              ..
#
# [2374 rows x 4 columns]

# %%
df_pollution_unpivot[mask].value_counts
# Out:
# <bound method DataFrame.value_counts of                 Country Name Country Code  Year PM2.5_pollution
# 9                      Aruba          ABW  2000              ..
# 27    British Virgin Islands          VGB  2000              ..
# 36            Cayman Islands          CYM  2000              ..
# 39           Channel Islands          CHI  2000              ..
# 50                   Curacao          CUW  2000              ..
# ...                      ...          ...   ...             ...
# 4769   Virgin Islands (U.S.)          VIR  2021              ..
# 4770      West Bank and Gaza          PSE  2021              ..
# 4771             Yemen, Rep.          YEM  2021              ..
# 4772                  Zambia          ZMB  2021              ..
# 4773                Zimbabwe          ZWE  2021              ..
#
# [2374 rows x 4 columns]>

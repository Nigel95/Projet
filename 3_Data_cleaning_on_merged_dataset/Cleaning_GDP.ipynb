# %%
pip install pandas
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting pandas
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/87/03/fe50521919aa981f6a1c197037da4623a267b0e5f42246d69ba048e86da3/pandas-2.2.0-cp312-cp312-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for numpy<2,>=1.26.0 from https://files.pythonhosted.org/packages/ad/11/52fbe97fd84c91105b651d25a122f8deed6d3519afb14f9771fac1c9b7de/numpy-1.26.3-cp312-cp312-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/61.2 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/61.2 kB 640.0 kB/s eta 0:00:01
#      ---------------------------------------- 61.2/61.2 kB 1.1 MB/s eta 0:00:00
# ...
#   Obtaining dependency information for pytz>=2020.1 from https://files.pythonhosted.org/packages/32/4d/aaf7eff5deb402fd9a24a1449a8119f00d74ae9c2efa79f8ef9994261fc2/pytz-2023.3.post1-py2.py3-none-any.whl.metadata
# ...

# %%
import pandas as pd

# %%
df_GDP_cleaning = pd.read_csv(r"C:\Users\nigel.zannou\Desktop\Projet\3_Data_cleaning_on_merged_dataset\merged_dataset_to_clean.csv",index_col=0)

# %%
df_GDP_cleaning.head()
# Out:
#            Country Name Country Code  Year  Birth Rate  GDP per Capita  \
# 0           Afghanistan          AFG  2000      49.664             NaN
# 1                Angola          AGO  2000      47.647      556.884244
# 2               Albania          ALB  2000      17.076     1126.683340
# 3               Andorra          AND  2000      11.300    21620.465102
# 4  United Arab Emirates          ARE  2000      16.660    31855.500605
#
#    Population_male  Population_female  Population_total  15_to_19_women_rate  \
# 0          9815442            9727541          19542982             9.898899
# 1          8054751            8339311          16394062            10.266795
# 2          1531486            1557540           3089027             9.699775
# 3            34285              31812             66097             5.158431
# 4          2237588            1037745           3275333            12.375337
#
#    20_to_24_women_rate  25_to_29_women_rate  30_to_34_women_rate  \
# ...

# %% [markdown]
# # Remplacement des valeurs manquantes pour l'Afgahanistan pour 2000 et 2001

# %%
df_GDP_cleaning.loc[(df_GDP_cleaning['Country Name'] == 'Afghanistan') & (df_GDP_cleaning['Year'] == 2001), 'GDP per Capita'] = 125
df_GDP_cleaning.loc[(df_GDP_cleaning['Country Name'] == 'Afghanistan') & (df_GDP_cleaning['Year'] == 2000), 'GDP per Capita'] = 181
df_GDP_cleaning
# Out:
#               Country Name Country Code  Year  Birth Rate  GDP per Capita  \
# 0              Afghanistan          AFG  2000      49.664      181.000000
# 1                   Angola          AGO  2000      47.647      556.884244
# 2                  Albania          ALB  2000      17.076     1126.683340
# 3                  Andorra          AND  2000      11.300    21620.465102
# 4     United Arab Emirates          ARE  2000      16.660    31855.500605
# ...                    ...          ...   ...         ...             ...
# 3557               Vanuatu          VUT  2021      29.438     3044.573640
# 3558                 Samoa          WSM  2021      27.254     3857.689742
# 3559          South Africa          ZAF  2021      19.821     7073.612754
# 3560                Zambia          ZMB  2021      34.511     1134.713454
# 3561              Zimbabwe          ZWE  2021      30.537     1773.920411
#
#       Population_male  Population_female  Population_total  \
# ...

# %%
df_GDP_cleaning.loc[df_GDP_cleaning["Country Name"]=="Afghanistan"]
# Out:
#      Country Name Country Code  Year  Birth Rate  GDP per Capita  \
# 0     Afghanistan          AFG  2000      49.664      181.000000
# 152   Afghanistan          AFG  2001      48.979      125.000000
# 304   Afghanistan          AFG  2002      48.201      182.174037
# 458   Afghanistan          AFG  2003      47.350      199.643228
# 614   Afghanistan          AFG  2004      46.330      221.830531
# 771   Afghanistan          AFG  2005      45.263      254.115274
# 932   Afghanistan          AFG  2006      44.721      274.015394
# 1093  Afghanistan          AFG  2007      43.858      376.318296
# 1255  Afghanistan          AFG  2008      41.506      382.533804
# 1417  Afghanistan          AFG  2009      41.157      453.387382
# 1579  Afghanistan          AFG  2010      40.602      562.499219
# 1743  Afghanistan          AFG  2011      39.855      608.738856
# 1908  Afghanistan          AFG  2012      40.009      653.417479
# ...

# %% [markdown]
# # Remplacement des valeurs manquantes pour Sao Tome et Principe pour 2000

# %%
df_GDP_cleaning.loc[(df_GDP_cleaning['Country Name'] == 'Sao Tome and Principe') & (df_GDP_cleaning['Year'] == 2000), 'GDP per Capita'] = 557

# %%
df_GDP_cleaning.loc[df_GDP_cleaning["Country Name"]=="Sao Tome and Principe"]
# Out:
#                Country Name Country Code  Year  Birth Rate  GDP per Capita  \
# 129   Sao Tome and Principe          STP  2000      39.438      557.000000
# 281   Sao Tome and Principe          STP  2001      39.941      519.295583
# 435   Sao Tome and Principe          STP  2002      39.850      568.409673
# 591   Sao Tome and Principe          STP  2003      39.633      663.920664
# 747   Sao Tome and Principe          STP  2004      39.396      726.597741
# 906   Sao Tome and Principe          STP  2005      39.075      843.955111
# 1067  Sao Tome and Principe          STP  2006      38.672      861.518202
# 1229  Sao Tome and Principe          STP  2007      38.241      878.135470
# 1391  Sao Tome and Principe          STP  2008      37.810     1080.556568
# 1553  Sao Tome and Principe          STP  2009      37.336     1126.538585
# 1717  Sao Tome and Principe          STP  2010      36.873     1043.281427
# ...

# %%
import pandas as pd
import numpy as np

# %%
df_education = pd.read_csv("C:\\Users\\celia\\Downloads\\EAG_NEAC_19012024111445270.csv")

# %%
df_education.shape
# Out:
# (60379, 25)

# %%
df_education.head()
# Out:
#   COUNTRY Country    ISC11A  \
# 0     SWE  Sweden  L3_T_SC2
# 1     SWE  Sweden  L3_T_SC2
# 2     SWE  Sweden  L3_T_SC2
# 3     SWE  Sweden  L3_T_SC2
# 4     SWE  Sweden  L3_T_SC2
#
#                         ISCED 2011 A education level SEX Gender     AGE  \
# 0  Completion of intermediate upper secondary pro...   T  Total  Y25T64
# 1  Completion of intermediate upper secondary pro...   T  Total  Y25T64
# 2  Completion of intermediate upper secondary pro...   T  Total  Y25T64
# 3  Completion of intermediate upper secondary pro...   T  Total  Y25T64
# 4  Completion of intermediate upper secondary pro...   T  Total  Y25T64
#
#            Age FIELD  Field  ... Reference year Unit Code Unit PowerCode Code  \
# 0  25-64 years     T  Total  ...           2014       NaN  NaN              0
# 1  25-64 years     T  Total  ...           2015       NaN  NaN              0
# 2  25-64 years     T  Total  ...           2016       NaN  NaN              0
# ...

# %%
df_education.tail()
# Out:
#       COUNTRY  Country ISC11A           ISCED 2011 A education level SEX  \
# 60374     ROU  Romania     L8       Doctoral or equivalent education   M
# 60375     ROU  Romania     L4  Post-secondary non-tertiary education   T
# 60376     ROU  Romania     L4  Post-secondary non-tertiary education   T
# 60377     ROU  Romania     L4  Post-secondary non-tertiary education   T
# 60378     ROU  Romania     L5         Short-cycle tertiary education   F
#
#       Gender     AGE          Age FIELD  Field  ...         Reference year  \
# 60374    Men  Y25T64  25-64 years     T  Total  ...  Latest available year
# 60375  Total  Y25T64  25-64 years     T  Total  ...                   2015
# 60376  Total  Y25T64  25-64 years     T  Total  ...                   2021
# 60377  Total  Y25T64  25-64 years     T  Total  ...  Latest available year
# 60378  Women  Y25T64  25-64 years     T  Total  ...                   2021
#
# ...

# %%
df_education.columns
# Out:
# Index(['COUNTRY', 'Country', 'ISC11A', 'ISCED 2011 A education level', 'SEX',
#        'Gender', 'AGE', 'Age', 'FIELD', 'Field', 'MEASURE', 'Measure',
#        'INDICATOR', 'INDICATOR.1', 'YEAR', 'Reference year', 'Unit Code',
#        'Unit', 'PowerCode Code', 'PowerCode', 'Reference Period Code',
#        'Reference Period', 'Value', 'Flag Codes', 'Flags'],
#       dtype='object')

# %%
df_education['Reference year'].value_counts()
# Out:
# Latest available year    3369
# 2020                     3321
# 2015                     3282
# 2019                     3224
# 2018                     3194
# 2017                     3182
# 2021                     3182
# 2016                     3083
# 2014                     2990
# 2013                     2640
# 2011                     2541
# 2012                     2496
# 2010                     2475
# 2009                     2322
# 2005                     2253
# 2008                     2241
# 2006                     2211
# 2007                     2190
# 2000                     2097
# 2004                     2078
# 2003                     2037
# 2002                     2007
# 2001                     1964
# Name: Reference year, dtype: int64

# %%
df_education['ISCED 2011 A education level'].value_counts()
# Out:
# Upper secondary or post-secondary non-tertiary education    4665
# Below upper secondary education                             4665
# Tertiary education                                          4665
# Lower secondary education                                   4557
# Bachelor’s or equivalent education                          4551
# Upper secondary education                                   4521
# Primary education                                           4378
# Master’s or equivalent education                            4365
# Doctoral or equivalent education                            4281
# Short-cycle tertiary education                              4271
# Less than primary education                                 4161
# Post-secondary non-tertiary education                       4063
# Completion of intermediate upper secondary programmes       3681
# Completion of intermediate lower secondary programmes       3555
# Name: ISCED 2011 A education level, dtype: int64

# %%
df_education = df_education.loc[df_education['ISCED 2011 A education level']== 'Upper secondary education',:]

# %%
df_education.head()
# Out:
#    COUNTRY   Country ISC11A ISCED 2011 A education level SEX Gender     AGE  \
# 59     PRT  Portugal     L3    Upper secondary education   T  Total  Y25T64
# 60     PRT  Portugal     L3    Upper secondary education   T  Total  Y25T64
# 61     PRT  Portugal     L3    Upper secondary education   T  Total  Y25T64
# 62     PRT  Portugal     L3    Upper secondary education   T  Total  Y25T64
# 63     PRT  Portugal     L3    Upper secondary education   T  Total  Y25T64
#
#             Age FIELD  Field  ... Reference year Unit Code Unit  \
# 59  25-64 years     T  Total  ...           2014       NaN  NaN
# 60  25-64 years     T  Total  ...           2015       NaN  NaN
# 61  25-64 years     T  Total  ...           2016       NaN  NaN
# 62  25-64 years     T  Total  ...           2017       NaN  NaN
# 63  25-64 years     T  Total  ...           2018       NaN  NaN
#
#    PowerCode Code  PowerCode Reference Period Code Reference Period     Value  \
# ...

# %%
df_education['Gender'].value_counts()
# Out:
# Total    1507
# Women    1507
# Men      1507
# Name: Gender, dtype: int64

# %%
df_education = df_education.loc[df_education['Gender']== 'Women',:]

# %%
df_education.describe(include='all')
# Out:
#        COUNTRY        Country ISC11A ISCED 2011 A education level   SEX  \
# count     1507           1507   1507                         1507  1507
# unique      49             49      1                            1     1
# top        USA  United States     L3    Upper secondary education     F
# freq        46             46   1507                         1507  1507
# mean       NaN            NaN    NaN                          NaN   NaN
# std        NaN            NaN    NaN                          NaN   NaN
# min        NaN            NaN    NaN                          NaN   NaN
# 25%        NaN            NaN    NaN                          NaN   NaN
# 50%        NaN            NaN    NaN                          NaN   NaN
# 75%        NaN            NaN    NaN                          NaN   NaN
# max        NaN            NaN    NaN                          NaN   NaN
#
#        Gender     AGE          Age FIELD  Field  ...         Reference year  \
# ...

# %%
df_education = df_education[df_education['Reference year'] != 'Latest available year']

# %%
df_education['YEAR'].value_counts()
# Out:
# 2020    86
# 2015    84
# 2019    83
# 2017    82
# 2018    82
# 2021    81
# 2016    79
# 2014    76
# 2013    65
# 2011    63
# 2010    61
# 2012    61
# 2009    56
# 2008    54
# 2005    54
# 2006    53
# 2007    53
# 2000    51
# 2003    50
# 2004    50
# 2002    49
# 2001    48
# Name: YEAR, dtype: int64

# %%
df_education = df_education[['COUNTRY', 'Country','SEX','YEAR', 'Value']]

# %%
df_education.describe()
# Out:
#               YEAR       Value
# count  1421.000000  912.000000
# mean   2011.771288   19.544464
# std       6.296918   19.391410
# min    2000.000000    0.066387
# 25%    2007.000000    0.240390
# 50%    2013.000000   18.422411
# 75%    2017.000000   35.893354
# max    2021.000000   68.810608

# %%
df_education.isna().sum()/len(df_education)
# Out:
# COUNTRY    0.000000
# Country    0.000000
# SEX        0.000000
# YEAR       0.000000
# Value      0.358198
# dtype: float64

# %%
df_education
# Out:
#       COUNTRY                              Country SEX  YEAR      Value
# 422       LUX                           Luxembourg   F  2000        NaN
# 423       LUX                           Luxembourg   F  2005        NaN
# 424       LUX                           Luxembourg   F  2006        NaN
# 425       LUX                           Luxembourg   F  2007        NaN
# 426       LUX                           Luxembourg   F  2008        NaN
# ...       ...                                  ...  ..   ...        ...
# 60005     E25  EU25: European Union of twenty-five   F  2021  37.074385
# 60287     ROU                              Romania   F  2015  45.480263
# 60288     ROU                              Romania   F  2021  49.244854
# 60337     ROU                              Romania   F  2015   0.189326
# 60338     ROU                              Romania   F  2021   0.206830
#
# [1421 rows x 5 columns]

# %%
df_education['Country'].value_counts()
# Out:
# United States                          44
# Latvia                                 44
# Greece                                 44
# Estonia                                44
# Costa Rica                             44
# G20                                    43
# Iceland                                41
# Mexico                                 39
# OECD - Average                         36
# Denmark                                35
# Colombia                               34
# Indonesia                              33
# Argentina                              32
# France                                 31
# Netherlands                            31
# Portugal                               30
# Italy                                  30
# Switzerland                            30
# Hungary                                30
# Slovak Republic                        30
# Germany                                30
# Spain                                  30
# ...

# %%
df_education = df_education[df_education['Country'] != 'G20']

# %%
df_education = df_education[df_education['Country'] != 'OECD - Average']

# %%
df_education = df_education[df_education['Country'] != 'EU25: European Union of twenty-five']

# %%
df_education['Country'].value_counts()
# Out:
# Costa Rica                      44
# Estonia                         44
# United States                   44
# Greece                          44
# Latvia                          44
# Iceland                         41
# Mexico                          39
# Denmark                         35
# Colombia                        34
# Indonesia                       33
# Argentina                       32
# France                          31
# Netherlands                     31
# Switzerland                     30
# Italy                           30
# Slovak Republic                 30
# Germany                         30
# Belgium                         30
# Sweden                          30
# Portugal                        30
# Czechia                         30
# United Kingdom                  30
# Spain                           30
# Hungary                         30
# Lithuania                       29
# Ireland                         29
# Austria                         29
# ...

# %%
df_education[df_education.isna().any(axis=1)]
# Out:
#       COUNTRY     Country SEX  YEAR  Value
# 422       LUX  Luxembourg   F  2000    NaN
# 423       LUX  Luxembourg   F  2005    NaN
# 424       LUX  Luxembourg   F  2006    NaN
# 425       LUX  Luxembourg   F  2007    NaN
# 426       LUX  Luxembourg   F  2008    NaN
# ...       ...         ...  ..   ...    ...
# 55486     IRL     Ireland   F  2009    NaN
# 55487     IRL     Ireland   F  2010    NaN
# 55488     IRL     Ireland   F  2011    NaN
# 55489     IRL     Ireland   F  2012    NaN
# 55490     IRL     Ireland   F  2013    NaN
#
# [433 rows x 5 columns]

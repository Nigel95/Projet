# %%
import pandas as pd

# %%
df_population = pd.read_csv("Dataset_male_and_female_population.csv")
display(df_population)
df_median_age = pd.read_csv("Dataset_median_age.csv")
display(df_median_age)
df_women_age_ratios = pd.read_csv("Dataset_women_age_ratios.csv")
display(df_population)
# Out:
#       Unnamed: 0                                Country Name Country Code  \
# 0              0                                 Afghanistan          AFG
# 1              1                                     Albania          ALB
# 2              2                                     Algeria          DZA
# 3              3                              American Samoa          ASM
# 4              4                                     Andorra          AND
# ...          ...                                         ...          ...
# 5847        5847                          Sub-Saharan Africa          SSF
# 5848        5848  Sub-Saharan Africa (excluding high income)          SSA
# 5849        5849   Sub-Saharan Africa (IDA & IBRD countries)          TSS
# 5850        5850                         Upper middle income          UMC
# 5851        5851                                       World          WLD
#
#       Year Population_male Population_female Population_total
# ...

# %%
merged_demography_dataset = df_population.merge(
                                                df_women_age_ratios,
                                                left_on=["Country Name", "Country Code", "Year"],
                                                right_on=["Country Name", "Country Code", "Year"],
                                                how="inner"
                                                ).merge(
                                                        df_median_age,
                                                        left_on=["Country Code", "Year"],
                                                        right_on=["Country Code", "Year"],
                                                        how="inner"
                                                        )
display(merged_demography_dataset)
# Out:
#       Unnamed: 0_x                                  Country Name Country Code  \
# 0                0                                   Afghanistan          AFG
# 1                1                                       Albania          ALB
# 2                2                                       Algeria          DZA
# 3                3                                American Samoa          ASM
# 4                4                                       Andorra          AND
# ...            ...                                           ...          ...
# 4923          5829  Least developed countries: UN classification          LDC
# 4924          5831                                    Low income          LIC
# 4925          5832                           Lower middle income          LMC
# 4926          5850                           Upper middle income          UMC
# 4927          5851                                         World          WLD
#
# ...

# %%
final_merged_demography_dataset = merged_demography_dataset.drop(["Unnamed: 0_x", "Unnamed: 0_y", "Unnamed: 0"], axis=1)
display(final_merged_demography_dataset)
# Out:
#                                       Country Name Country Code  Year  \
# 0                                      Afghanistan          AFG  2000
# 1                                          Albania          ALB  2000
# 2                                          Algeria          DZA  2000
# 3                                   American Samoa          ASM  2000
# 4                                          Andorra          AND  2000
# ...                                            ...          ...   ...
# 4923  Least developed countries: UN classification          LDC  2021
# 4924                                    Low income          LIC  2021
# 4925                           Lower middle income          LMC  2021
# 4926                           Upper middle income          UMC  2021
# 4927                                         World          WLD  2021
#
#      Population_male Population_female Population_total 15_to_19_women_rate  \
# ...

# %%
final_merged_demography_dataset.to_csv('Demography_dataset.csv')

# %%
final_merged_demography_dataset.describe()
# Out:
#               Year   Median_age
# count  4928.000000  4907.000000
# mean   2010.500000    27.524047
# std       6.344933     8.793397
# min    2000.000000     0.000000
# 25%    2005.000000    19.400000
# 50%    2010.500000    26.600000
# 75%    2016.000000    35.600000
# max    2021.000000    54.500000

# %%
final_merged_demography_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4928 entries, 0 to 4927
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Country Name         4928 non-null   object
#  1   Country Code         4928 non-null   object
#  2   Year                 4928 non-null   int64
#  3   Population_male      4928 non-null   object
#  4   Population_female    4928 non-null   object
#  5   Population_total     4928 non-null   object
#  6   15_to_19_women_rate  4928 non-null   object
#  7   20_to_24_women_rate  4928 non-null   object
#  8   25_to_29_women_rate  4928 non-null   object
#  9   30_to_34_women_rate  4928 non-null   object
#  10  35_to_39_women_rate  4928 non-null   object
#  11  40_to_44_women_rate  4928 non-null   object
#  12  Median_age           4907 non-null   float64
# dtypes: float64(1), int64(1), object(11)
# memory usage: 500.6+ KB

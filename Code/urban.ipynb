# %%
import pandas as pd
import numpy as np

# %%
df_urban = pd.read_csv("C:\\Users\\celia\\Downloads\\c2c5ffe7-2aee-4405-a4c4-b1669bd45d7f_Data.csv")

# %%
df_urban.shape
# Out:
# (222, 26)

# %%
df_urban.head()
# Out:
#      Country Name Country Code                               Series Name  \
# 0     Afghanistan          AFG  Urban population (% of total population)
# 1         Albania          ALB  Urban population (% of total population)
# 2         Algeria          DZA  Urban population (% of total population)
# 3  American Samoa          ASM  Urban population (% of total population)
# 4         Andorra          AND  Urban population (% of total population)
#
#          Series Code 2000 [YR2000] 2001 [YR2001] 2002 [YR2002] 2003 [YR2003]  \
# 0  SP.URB.TOTL.IN.ZS        22.078        22.169        22.261        22.353
# 1  SP.URB.TOTL.IN.ZS        41.741        42.435        43.501        44.573
# 2  SP.URB.TOTL.IN.ZS        59.919        60.712        61.501        62.284
# 3  SP.URB.TOTL.IN.ZS        88.587        88.491        88.394        88.297
# 4  SP.URB.TOTL.IN.ZS        92.395        92.056        91.641        91.207
#
# ...

# %%
df_urban.tail(10)
# Out:
#                                          Country Name Country Code  \
# 212                             Virgin Islands (U.S.)          VIR
# 213                                West Bank and Gaza          PSE
# 214                                       Yemen, Rep.          YEM
# 215                                            Zambia          ZMB
# 216                                          Zimbabwe          ZWE
# 217                                               NaN          NaN
# 218                                               NaN          NaN
# 219                                               NaN          NaN
# 220  Data from database: World Development Indicators          NaN
# 221                          Last Updated: 12/18/2023          NaN
#
#                                   Series Name        Series Code  \
# 212  Urban population (% of total population)  SP.URB.TOTL.IN.ZS
# 213  Urban population (% of total population)  SP.URB.TOTL.IN.ZS
# ...

# %%
df_urban= df_urban.iloc[:-5,]

# %%
df_urban.tail()
# Out:
#               Country Name Country Code  \
# 212  Virgin Islands (U.S.)          VIR
# 213     West Bank and Gaza          PSE
# 214            Yemen, Rep.          YEM
# 215                 Zambia          ZMB
# 216               Zimbabwe          ZWE
#
#                                   Series Name        Series Code  \
# 212  Urban population (% of total population)  SP.URB.TOTL.IN.ZS
# 213  Urban population (% of total population)  SP.URB.TOTL.IN.ZS
# 214  Urban population (% of total population)  SP.URB.TOTL.IN.ZS
# 215  Urban population (% of total population)  SP.URB.TOTL.IN.ZS
# 216  Urban population (% of total population)  SP.URB.TOTL.IN.ZS
#
#     2000 [YR2000] 2001 [YR2001] 2002 [YR2002] 2003 [YR2003] 2004 [YR2004]  \
# 212        92.586        92.814        93.036        93.251        93.461
# 213        71.969        72.189        72.409        72.627        72.845
# 214        26.267        26.787        27.315        27.849         28.39
# ...

# %%
df_urban = df_urban.drop(columns=['Series Name', 'Series Code'])

# %%
df_urban.info(all)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 217 entries, 0 to 216
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country Name   217 non-null    object
#  1   Country Code   217 non-null    object
#  2   2000 [YR2000]  217 non-null    object
#  3   2001 [YR2001]  217 non-null    object
#  4   2002 [YR2002]  217 non-null    object
#  5   2003 [YR2003]  217 non-null    object
#  6   2004 [YR2004]  217 non-null    object
#  7   2005 [YR2005]  217 non-null    object
#  8   2006 [YR2006]  217 non-null    object
#  9   2007 [YR2007]  217 non-null    object
#  10  2008 [YR2008]  217 non-null    object
#  11  2009 [YR2009]  217 non-null    object
#  12  2010 [YR2010]  217 non-null    object
#  13  2011 [YR2011]  217 non-null    object
#  14  2012 [YR2012]  217 non-null    object
#  15  2013 [YR2013]  217 non-null    object
#  16  2014 [YR2014]  217 non-null    object
# ...

# %%
df_urban.describe(include='all')
# Out:
#        Country Name Country Code 2000 [YR2000] 2001 [YR2001] 2002 [YR2002]  \
# count           217          217           217           217           217
# unique          217          217           207           207           207
# top     Afghanistan          AFG           100           100           100
# freq              1            1             9             9            10
#
#        2003 [YR2003] 2004 [YR2004] 2005 [YR2005] 2006 [YR2006] 2007 [YR2007]  \
# count            217           217           217           217           217
# unique           207           207           207           207           207
# top              100           100           100           100           100
# freq              10            10            10            10            10
#
#         ... 2012 [YR2012] 2013 [YR2013] 2014 [YR2014] 2015 [YR2015]  \
# count   ...           217           217           217           217
# ...

# %%
columns_to_modify = df_urban.columns[2:]
columns_to_modify = columns_to_modify.str.replace(r'\[YR\d{4}\]','')
# Out:
# C:\Users\celia\AppData\Local\Temp\ipykernel_10976\3924213701.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   columns_to_modify = columns_to_modify.str.replace(r'\[YR\d{4}\]','')

# %%
columns_to_modify
# Out:
# Index(['2000 ', '2001 ', '2002 ', '2003 ', '2004 ', '2005 ', '2006 ', '2007 ',
#        '2008 ', '2009 ', '2010 ', '2011 ', '2012 ', '2013 ', '2014 ', '2015 ',
#        '2016 ', '2017 ', '2018 ', '2019 ', '2020 ', '2021 '],
#       dtype='object')

# %%
df_urban.columns =['Country Name','Country Code', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
       '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
       '2016', '2017', '2018', '2019', '2020', '2021']

# %%
df_urban_unpivot= df_urban.melt(id_vars=['Country Name','Country Code'], var_name = 'Year', value_name= 'Urban population rate')

# %%
df_urban_unpivot
# Out:
#                Country Name Country Code  Year Urban population rate
# 0               Afghanistan          AFG  2000                22.078
# 1                   Albania          ALB  2000                41.741
# 2                   Algeria          DZA  2000                59.919
# 3            American Samoa          ASM  2000                88.587
# 4                   Andorra          AND  2000                92.395
# ...                     ...          ...   ...                   ...
# 4769  Virgin Islands (U.S.)          VIR  2021                 96.04
# 4770     West Bank and Gaza          PSE  2021                77.003
# 4771            Yemen, Rep.          YEM  2021                38.546
# 4772                 Zambia          ZMB  2021                45.192
# 4773               Zimbabwe          ZWE  2021                32.303
#
# [4774 rows x 4 columns]

# %%
df_urban_unpivot.describe(include='all')
# Out:
#        Country Name Country Code  Year Urban population rate
# count          4774         4774  4774                  4774
# unique          217          217    22                  4380
# top     Afghanistan          AFG  2000                   100
# freq             22           22   217                   218

# %%
mask = df_urban_unpivot['Urban population rate'].str.contains(r'\.\.', na=False)
print(df_urban_unpivot[mask])
# Out:
#                   Country Name Country Code  Year Urban population rate
# 105                     Kosovo          XKX  2000                    ..
# 183   St. Martin (French part)          MAF  2000                    ..
# 322                     Kosovo          XKX  2001                    ..
# 400   St. Martin (French part)          MAF  2001                    ..
# 539                     Kosovo          XKX  2002                    ..
# 617   St. Martin (French part)          MAF  2002                    ..
# 756                     Kosovo          XKX  2003                    ..
# 834   St. Martin (French part)          MAF  2003                    ..
# 973                     Kosovo          XKX  2004                    ..
# 1051  St. Martin (French part)          MAF  2004                    ..
# 1190                    Kosovo          XKX  2005                    ..
# 1268  St. Martin (French part)          MAF  2005                    ..
# ...

# %%
df_urban_unpivot[mask].value_counts
# Out:
# <bound method DataFrame.value_counts of                   Country Name Country Code  Year Urban population rate
# 105                     Kosovo          XKX  2000                    ..
# 183   St. Martin (French part)          MAF  2000                    ..
# 322                     Kosovo          XKX  2001                    ..
# 400   St. Martin (French part)          MAF  2001                    ..
# 539                     Kosovo          XKX  2002                    ..
# 617   St. Martin (French part)          MAF  2002                    ..
# 756                     Kosovo          XKX  2003                    ..
# 834   St. Martin (French part)          MAF  2003                    ..
# 973                     Kosovo          XKX  2004                    ..
# 1051  St. Martin (French part)          MAF  2004                    ..
# 1190                    Kosovo          XKX  2005                    ..
# ...
